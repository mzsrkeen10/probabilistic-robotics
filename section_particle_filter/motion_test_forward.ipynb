# %%
import copy
import sys
import pandas as pd
sys.path.append("../scripts")
from robot import *

# %%
world = World(40.0, 0.1)

initial_pose = np.array([0, 0, 0]).T
robots = []
r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))

for _ in range(100):
    copy_r = copy.copy(r)
    copy_r.distance_until_noise = copy_r.noise_pdf.rvs()
    world.append(copy_r)
    robots.append(copy_r)

world.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=["r", "theta"])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      3.884527  3.895265  3.901497  3.902708  3.887918  3.885787  3.900852
# theta  0.201389 -0.193030  0.124333 -0.155055  0.224544  0.258126 -0.106903
#
#              7         8         9   ...        90        91        92  \
# r      3.904457  3.906615  3.902219  ...  3.901607  3.904717  3.901112
# theta -0.044758  0.035578 -0.095040  ... -0.060818 -0.090639  0.112309
#
#              93        94        95        96        97        98        99
# r      3.895581  3.886596  3.903054  3.899531  3.891095  3.907290  3.886710
# theta -0.169523 -0.199642 -0.080044 -0.228645  0.222093  0.011187  0.248959
#
# [2 rows x 100 columns]

# %%
print(poses["theta"].var())
print(poses["r"].mean())
math.sqrt(poses["theta"].var() / poses["r"].mean())
# Out:
# 0.05085536736898395
# 3.8926542634945696
# 0.11429980296912022

# %%
world = World(40.0, 0.1)

initial_pose = np.array([0, 0, 0]).T
robots = []

for _ in range(100):
    r = Robot(initial_pose, sensor=None, agent=Agent(0.1, 0.0))
    world.append(r)
    robots.append(r)

world.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
poses = pd.DataFrame([[math.sqrt(r.pose[0]**2 + r.pose[1]**2), r.pose[2]] for r in robots], columns=["r", "theta"])
poses.transpose()
# Out:
#              0         1         2         3         4         5         6   \
# r      3.942049  3.954839  3.103488  4.096954  4.734858  4.077875  4.934954
# theta  0.235368  0.243411 -0.150344 -0.104156 -0.224807 -0.173983 -0.170569
#
#              7         8         9   ...        90        91        92  \
# r      3.556486  4.087075  4.231085  ...  3.329369  3.246482  4.055570
# theta  0.142415 -0.054618  0.172772  ... -0.057526 -0.140404  0.094338
#
#              93        94        95        96        97        98        99
# r      4.015270  4.056079  4.335032  4.298360  4.065937  3.759428  3.751309
# theta -0.284831  0.221313  0.011249  0.117663  0.606904 -0.230240 -0.065154
#
# [2 rows x 100 columns]

# %%
print(poses["r"].var())
print(poses["r"].mean())
math.sqrt(poses["r"].var() / poses["r"].mean())
# Out:
# 0.19252797490435594
# 4.007988970363844
# 0.2191712893446418
